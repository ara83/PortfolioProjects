# %%
# First let's import the packages we will use in this project

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r'C:\Users\aravi\Downloads\movies.csv')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Finding missing datas

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Data Types for our columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#Changing data types of columns

df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0).astype(int)
df['gross'] = pd.to_numeric(df['gross'], errors='coerce').fillna(0).astype(int)

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Create correct year column

df['yearcorrect'] = df['released'].astype(str).str.split().str[2]

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Order our Data a little bit to see

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13     Action  2015
# 7244                      Avengers: Infinity War      PG-13     Action  2018
# 7480                               The Lion King         PG  Animation  2019
# 6653                              Jurassic World      PG-13     Action  2015
# 6043                                The Avengers      PG-13     Action  2012
# ...                                          ...        ...        ...   ...
# 5033                            Loving Annabelle  Not Rated      Drama  2006
# 7667                                   Tee em el        NaN     Horror  2020
# 3045                                     Titanic      PG-13      Drama  1997
# 7445                           Avengers: Endgame      PG-13     Action  2019
# 5445                                      Avatar      PG-13     Action  2009
#
# ...

# %%
pd.set_option('display.max_rows', 100)

# %%
df.head(100)
# Out:
#                                                  name     rating      genre  \
# 0                                         The Shining          R      Drama
# 1                                     The Blue Lagoon          R  Adventure
# 2      Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                           Airplane!         PG     Comedy
# 4                                          Caddyshack          R     Comedy
# 5                                     Friday the 13th          R     Horror
# 6                                  The Blues Brothers          R     Action
# 7                                         Raging Bull          R  Biography
# 8                                         Superman II         PG     Action
# 9                                     The Long Riders          R  Biography
# 10                              Any Which Way You Can         PG     Action
# ...

# %%
# Dropping duplicate

df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#budget high correlation

#company high correlation

# %%
#scatter plot for budget vs gross


df.fillna(0, inplace=True)
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross earnings')
plt.xlabel('Budget')
plt.ylabel('Gross')

plt.show()

# %%
#plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws = {"color": "red"}, line_kws={"color":"purple"})

plt.show()

# %%
#Looking at correlation # pearson, kendall , spearman

df.corr(numeric_only=True, method ='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.256331  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.169154  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.573930  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.687124  0.268372
# gross    0.256331  0.169154  0.573930  0.687124  1.000000  0.203616
# runtime  0.116358  0.394564  0.306984  0.268372  0.203616  1.000000

# %%
correlation_matrix = df.corr(numeric_only=True, method ='pearson')

sns.heatmap(correlation_matrix,annot= True)

plt.title('Correlation matrix for numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
df.dtypes
# Out:
# name           category
# rating         category
# genre              int8
# year              int64
# released          int16
# score           float64
# votes           float64
# director          int16
# writer            int16
# star              int16
# country            int8
# budget            int32
# gross             int32
# company           int16
# runtime         float64
# yearcorrect        int8
# dtype: object

# %%
for col in df_numerized.select_dtypes(['category']).columns:
    df_numerized[col] = df_numerized[col].cat.codes

df_numerized.dtypes
# Out:
# name             int16
# rating            int8
# genre             int8
# year             int64
# released         int16
# score          float64
# votes          float64
# director         int16
# writer           int16
# star             int16
# country           int8
# budget           int32
# gross            int32
# company          int16
# runtime        float64
# yearcorrect       int8
# dtype: object

# %%
df_numerized.columns = df_numerized.columns.str.strip()

# Step 2: Convert all object (text) columns to numeric codes
for col in df_numerized.columns:
    if df_numerized[col].dtype == 'object':  # for object/text columns
        df_numerized[col] = df_numerized[col].astype(str).str.strip()  # Clean any extra spaces
        df_numerized[col] = df_numerized[col].astype('category')  # Convert to category
        df_numerized[col] = df_numerized[col].cat.codes  # Convert to numeric codes

# Step 3: Convert all columns to integer type (if possible)
df_numerized = df_numerized.apply(pd.to_numeric, errors='coerce')

# Step 4: Convert any remaining float columns to int
df_numerized = df_numerized.fillna(0).astype(int)

# Step 5: Verify the DataFrame has been numerized (check data types)
df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 0     6587       7      6  1980      1706      8   927000      2589    4015
# 1     5573       7      1  1980      1493      5    65000      2269    1633
# 2     5142       5      0  1980      1772      8  1200000      1111    2568
# 3      286       5      4  1980      1493      7   221000      1301    2001
# 4     1027       7      4  1980      1544      7   108000      1054     522
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705       0      6  2020      2965      3       18      1500    2290
# 7664  1678       0      4  2020      1108      4       36       774    2615
# 7665  4717       0      6  2020       194      5       29      2061    2684
# 7666  2843       0      6  2020      2818      0        0      1184    1825
# 7667  5394       0     10  2020       392      5        7      2165    3345
#
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017191
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613  0.002753
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.023134
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.091429
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.038676
# score        0.017191  0.002753  0.023134  0.091429  0.038676  1.000000
# votes        0.013038  0.033743 -0.145296  0.222427  0.015878  0.391952
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.017562
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.022961
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000075
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.125743
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.053473
# ...

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#                               ...
# yearcorrect  budget         0.300649
#              gross          0.249548
#              company       -0.011060
#              runtime        0.120915
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
# gross        genre         -0.229534
# genre        gross         -0.229534
#              votes         -0.145296
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]

high_corr
# Out:
# gross        votes          0.573930
# votes        gross          0.573930
# budget       gross          0.687124
# gross        budget         0.687124
# year         yearcorrect    0.990063
# yearcorrect  year           0.990063
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#Votes and budget has highest correlation to gross earnings
