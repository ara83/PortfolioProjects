# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'50',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '7a7fc979-456c-45bd-92e3-f61954592a61',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2025-05-16T07:38:12.057Z', 'error_code': 0, 'error_message': None, 'elapsed': 24, 'credit_count': 1, 'notice': None, 'total_count': 9793}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 12069, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id                         name  symbol                     slug  \
# 0       1                      Bitcoin     BTC                  bitcoin
# 1    1027                     Ethereum     ETH                 ethereum
# 2     825                  Tether USDt    USDT                   tether
# 3      52                          XRP     XRP                      xrp
# 4    1839                          BNB     BNB                      bnb
# 5    5426                       Solana     SOL                   solana
# 6    3408                         USDC    USDC                 usd-coin
# 7      74                     Dogecoin    DOGE                 dogecoin
# 8    2010                      Cardano     ADA                  cardano
# 9    1958                         TRON     TRX                     tron
# 10  20947                          Sui     SUI                      sui
# 11   1975                    Chainlink    LINK                chainlink
# ...

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

def api_run():
    global df

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'20',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '7a7fc979-456c-45bd-92e3-f61954592a61',
    }
    
    session = Session()
    session.headers.update(headers)
    
    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    #df = pd.json_normalize(data['data'])
    #df['timestamp'] = pd.to_datetime('now')
    #df
    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C:\Users\aravi\OneDrive\Desktop\API.csv'):
        df.to_csv(r'C:\Users\aravi\OneDrive\Desktop\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\aravi\OneDrive\Desktop\API.csv', mode='a', header=False)
        
    #Then to read in the file: 
    #df = pd.read_csv(r'C:\Users\alexf\OneDrive\Documents\Python Scripts\API.csv')

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_run()
    print('API Runner completed')
    sleep(10) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       6     api_run()
#       7     print('API Runner completed')
# ----> 8     sleep(10) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.044328                      1.924650
# Ethereum                         0.568269                      2.600386
# Tether USDt                      0.003825                      0.004404
# XRP                             -0.485027                     -2.122301
# BNB                             -0.212672                      1.959773
# Solana                          -0.165576                      0.849528
# USDC                            -0.000879                      0.009440
# Dogecoin                        -0.257349                      0.631175
# Cardano                         -0.102219                      1.269375
# TRON                            -0.365478                      2.085439
# Sui                             -0.082590                      4.323478
# Chainlink                       -0.033211                      0.534497
# ...

# %%
#coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.044328                      1.924650
# Ethereum                         0.568269                      2.600386
# Tether USDt                      0.003825                      0.004404
# XRP                             -0.485027                     -2.122301
# BNB                             -0.212672                      1.959773
# Solana                          -0.165576                      0.849528
# USDC                            -0.000879                      0.009440
# Dogecoin                        -0.257349                      0.631175
# Cardano                         -0.102219                      1.269375
# TRON                            -0.365478                      2.085439
# Sui                             -0.082590                      4.323478
# Chainlink                       -0.033211                      0.534497
# ...

# %%
df4.count()
# Out:
# 120

# %%
index = pd.Index(range(120))


df6 = df4.reset_index()
df6
# Out:
#         name                       level_1          0
# 0    Bitcoin   quote.USD.percent_change_1h  -0.044328
# 1    Bitcoin  quote.USD.percent_change_24h   1.924650
# 2    Bitcoin   quote.USD.percent_change_7d   0.092072
# 3    Bitcoin  quote.USD.percent_change_30d  24.627970
# 4    Bitcoin  quote.USD.percent_change_60d  24.642252
# ..       ...                           ...        ...
# 115  Toncoin  quote.USD.percent_change_24h  -0.723945
# 116  Toncoin   quote.USD.percent_change_7d  -4.465312
# 117  Toncoin  quote.USD.percent_change_30d   9.409831
# 118  Toncoin  quote.USD.percent_change_60d  -8.888040
# 119  Toncoin  quote.USD.percent_change_90d -18.313295
#
# [120 rows x 3 columns]

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.044328                      1.924650
# Ethereum                         0.568269                      2.600386
# Tether USDt                      0.003825                      0.004404
# XRP                             -0.485027                     -2.122301
# BNB                             -0.212672                      1.959773
# Solana                          -0.165576                      0.849528
# USDC                            -0.000879                      0.009440
# Dogecoin                        -0.257349                      0.631175
# Cardano                         -0.102219                      1.269375
# TRON                            -0.365478                      2.085439
# Sui                             -0.082590                      4.323478
# Chainlink                       -0.033211                      0.534497
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin  quote.USD.percent_change_1h     -0.044328
#          quote.USD.percent_change_24h     1.924650
#          quote.USD.percent_change_7d      0.092072
#          quote.USD.percent_change_30d    24.627970
#          quote.USD.percent_change_60d    24.642252
#                                            ...
# Toncoin  quote.USD.percent_change_24h    -0.723945
#          quote.USD.percent_change_7d     -4.465312
#          quote.USD.percent_change_30d     9.409831
#          quote.USD.percent_change_60d    -8.888040
#          quote.USD.percent_change_90d   -18.313295
# Length: 120, dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                          values
# name
# Bitcoin quote.USD.percent_change_1h   -0.044328
#         quote.USD.percent_change_24h   1.924650
#         quote.USD.percent_change_7d    0.092072
#         quote.USD.percent_change_30d  24.627970
#         quote.USD.percent_change_60d  24.642252
# ...                                         ...
# Toncoin quote.USD.percent_change_24h  -0.723945
#         quote.USD.percent_change_7d   -4.465312
#         quote.USD.percent_change_30d   9.409831
#         quote.USD.percent_change_60d  -8.888040
#         quote.USD.percent_change_90d -18.313295
#
# [120 rows x 1 columns]

# %%
df5.count()
# Out:
# values    120
# dtype: int64

# %%
index = pd.Index(range(120))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6
# Out:
#         name                       level_1     values
# 0    Bitcoin   quote.USD.percent_change_1h  -0.044328
# 1    Bitcoin  quote.USD.percent_change_24h   1.924650
# 2    Bitcoin   quote.USD.percent_change_7d   0.092072
# 3    Bitcoin  quote.USD.percent_change_30d  24.627970
# 4    Bitcoin  quote.USD.percent_change_60d  24.642252
# ..       ...                           ...        ...
# 115  Toncoin  quote.USD.percent_change_24h  -0.723945
# 116  Toncoin   quote.USD.percent_change_7d  -4.465312
# 117  Toncoin  quote.USD.percent_change_30d   9.409831
# 118  Toncoin  quote.USD.percent_change_60d  -8.888040
# 119  Toncoin  quote.USD.percent_change_90d -18.313295
#
# [120 rows x 3 columns]

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#         name                percent_change     values
# 0    Bitcoin   quote.USD.percent_change_1h  -0.044328
# 1    Bitcoin  quote.USD.percent_change_24h   1.924650
# 2    Bitcoin   quote.USD.percent_change_7d   0.092072
# 3    Bitcoin  quote.USD.percent_change_30d  24.627970
# 4    Bitcoin  quote.USD.percent_change_60d  24.642252
# ..       ...                           ...        ...
# 115  Toncoin  quote.USD.percent_change_24h  -0.723945
# 116  Toncoin   quote.USD.percent_change_7d  -4.465312
# 117  Toncoin  quote.USD.percent_change_30d   9.409831
# 118  Toncoin  quote.USD.percent_change_60d  -8.888040
# 119  Toncoin  quote.USD.percent_change_90d -18.313295
#
# [120 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1hr','24h','7d','30d','60d','90d'])
df7
# Out:
#         name percent_change     values
# 0    Bitcoin            1hr  -0.044328
# 1    Bitcoin            24h   1.924650
# 2    Bitcoin             7d   0.092072
# 3    Bitcoin            30d  24.627970
# 4    Bitcoin            60d  24.642252
# ..       ...            ...        ...
# 115  Toncoin            24h  -0.723945
# 116  Toncoin             7d  -4.465312
# 117  Toncoin            30d   9.409831
# 118  Toncoin            60d  -8.888040
# 119  Toncoin            90d -18.313295
#
# [120 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
